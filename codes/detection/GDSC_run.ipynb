# %%
# !pip install ultralytics
# Out:
# ...
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/57/e4/762a111cb112f751eda6fa6716a97c00eecaff09e7d2d3835d96e29fcd5d/ultralytics-8.1.9-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/40.2 kB ? eta -:--:--
#      -------------------------------------- 40.2/40.2 kB 966.6 kB/s eta 0:00:00
# ...
#   Obtaining dependency information for torch>=1.8.0 from https://files.pythonhosted.org/packages/c8/ed/f11e9eb1e21d7ea8fc82a9fd373f9ff2023a7ee9e47d07c9bc9efce46eca/torch-2.2.0-cp310-cp310-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for torchvision>=0.9.0 from https://files.pythonhosted.org/packages/7f/c9/10ca7837d786f2a96328ddf3a93767897d5e6eb04cf42b043778a771d04a/torchvision-0.17.0-cp310-cp310-win_amd64.whl.metadata
# ...

# %%
from ultralytics import YOLO
model = YOLO("C:/Users/GF63/Downloads/best.pt")
results = model.predict(show = True, source = 0 )
# Out:
# 1/1: 0... Success ✅ (inf frames of shape 640x480 at 22.00 FPS)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 1 1, 147.1ms
# 0: 480x640 (no detections), 117.7ms
# 0: 480x640 1 1, 103.4ms
# 0: 480x640 1 1, 113.9ms
# 0: 480x640 1 1, 111.1ms
# 0: 480x640 1 1, 110.6ms
# 0: 480x640 1 1, 105.6ms
# 0: 480x640 1 1, 108.2ms
# 0: 480x640 (no detections), 112.6ms
# 0: 480x640 1 1, 112.5ms
# 0: 480x640 (no detections), 107.2ms
# 0: 480x640 (no detections), 110.6ms
# ...

# %%
Kq = results

# %%
import numpy
for R in Kq:
    boxes = R.boxes.cpu().numpy()
    xyxy = boxes.xyxy
    print(xyxy)
# Out:
# [[     361.69      182.57      655.62        1024]]
